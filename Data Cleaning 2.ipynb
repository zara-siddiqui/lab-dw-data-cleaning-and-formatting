# %%
import pandas as pd
import numpy as np

# %%
file = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv'
data = pd.read_csv(file)
display(data.head(3))
data.shape
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value   Income  \
# 0  RB50392  Washington    NaN    Master                     NaN      0.0
# 1  QZ44356     Arizona      F  Bachelor              697953.59%      0.0
# 2  AI49188      Nevada      F  Bachelor             1288743.17%  48767.0
#
#    Monthly Premium Auto Number of Open Complaints    Policy Type  \
# 0                1000.0                    1/0/00  Personal Auto
# 1                  94.0                    1/0/00  Personal Auto
# 2                 108.0                    1/0/00  Personal Auto
#
#    Vehicle Class  Total Claim Amount
# 0  Four-Door Car            2.704934
# 1  Four-Door Car         1131.464935
# 2   Two-Door Car          566.472247
# (4008, 11)

# %%
# Exercise 1: Cleaning Column Names

# %%
for column in data.columns:
    data_columns = data[column].unique()
    print(data_columns)
# Out:
# ['RB50392' 'QZ44356' 'AI49188' ... 'CW49887' 'MY31220' nan]
# ['Washington' 'Arizona' 'Nevada' 'California' 'Oregon' 'Cali' 'AZ' 'WA'
#  nan]
# [nan 'F' 'M' 'Femal' 'Male' 'female']
# ['Master' 'Bachelor' 'High School or Below' 'College' 'Bachelors' 'Doctor'
#  nan]
# [nan '697953.59%' '1288743.17%' ... '2031499.76%' '323912.47%'
#  '899704.02%']
# [    0. 48767. 36357. 62902. 55350. 14072. 28812. 77026. 99845. 83689.
#  24599. 25049. 28855. 51148. 66140. 57749. 61040. 17870. 97541. 29723.
#  86584. 75690. 23158. 65999. 37260. 68987. 42305. 65706. 53243. 50071.
#  60021. 43244. 46896. 10105. 23218. 24804. 33190. 36014. 67163. 16701.
#  46623. 64749. 16969. 11621. 17622. 11489. 66525. 33663. 22547. 61486.
#  29879. 93011. 65186. 26840. 75644. 38984. 71811. 20961. 41275. 61321.
#  51066. 34378. 43072. 25222. 77552. 23091. 48269. 32720. 20396. 21513.
#  80744. 52822. 69738. 17780. 18107. 57740. 32627. 65795. 60475. 41837.
# ...

# %%
cols = []
for column in data.columns:
    cols.append(column.lower())
cols
data.columns = cols
data
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
data.columns = data.columns.str.lower().str.replace(' ', '_')
data.head(2)
# Out:
#   customer          st gender education customer_lifetime_value  income  \
# 0  RB50392  Washington    NaN    Master                     NaN     0.0
# 1  QZ44356     Arizona      F  Bachelor              697953.59%     0.0
#
#    monthly_premium_auto number_of_open_complaints    policy_type  \
# 0                1000.0                    1/0/00  Personal Auto
# 1                  94.0                    1/0/00  Personal Auto
#
#    vehicle_class  total_claim_amount
# 0  Four-Door Car            2.704934
# 1  Four-Door Car         1131.464935

# %%
data = data.rename(columns = {"st":"state"})
data.head(2)
# Out:
#   customer       state gender education customer_lifetime_value  income  \
# 0  RB50392  Washington    NaN    Master                     NaN     0.0
# 1  QZ44356     Arizona      F  Bachelor              697953.59%     0.0
#
#    monthly_premium_auto number_of_open_complaints    policy_type  \
# 0                1000.0                    1/0/00  Personal Auto
# 1                  94.0                    1/0/00  Personal Auto
#
#    vehicle_class  total_claim_amount
# 0  Four-Door Car            2.704934
# 1  Four-Door Car         1131.464935

# %%
# Exercise 2: Cleaning invalid Values

# %%
data = data.drop_duplicates(subset=['customer'], keep = False)
print(data.shape)
data.tail(5)
# Out:
# (1071, 11)
#      customer       state gender             education  \
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 1066              305955.03%  38644.0                  78.0
# 1067             2031499.76%  63209.0                 102.0
# 1068              323912.47%  16061.0                  88.0
# 1069              462680.11%  79487.0                 114.0
# 1070              899704.02%  54230.0                 112.0
#
#      number_of_open_complaints    policy_type  vehicle_class  \
# 1066                    1/1/00  Personal Auto  Four-Door Car
# 1067                    1/2/00  Personal Auto            SUV
# 1068                    1/0/00  Personal Auto  Four-Door Car
# ...

# %%
data.isna().sum()
# Out:
# customer                       0
# state                          0
# gender                       117
# education                      0
# customer_lifetime_value        3
# income                         0
# monthly_premium_auto           0
# number_of_open_complaints      0
# policy_type                    0
# vehicle_class                  0
# total_claim_amount             0
# dtype: int64

# %%
data['gender'].value_counts(dropna=False)
# Out:
# F         457
# M         413
# NaN       117
# Male       39
# female     28
# Femal      17
# Name: gender, dtype: int64

# %%
data['gender'] = data['gender'].fillna('F')
data.head(5)
# Out:
#   customer       state gender             education customer_lifetime_value  \
# 0  RB50392  Washington      F                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
gender_column = data['gender'].unique()
print(gender_column)
# Out:
# ['F' 'M' 'Femal' 'Male' 'female']

# %%
valid_gender = {'F': 'Female', 'Femal': 'Female', 'female' : 'Female', 'M': 'Male'}
data['gender'] = data['gender'].replace(valid_gender)
data.head(5)
# Out:
#   customer       state  gender             education customer_lifetime_value  \
# 0  RB50392  Washington  Female                Master                     NaN
# 1  QZ44356     Arizona  Female              Bachelor              697953.59%
# 2  AI49188      Nevada  Female              Bachelor             1288743.17%
# 3  WW63253  California    Male              Bachelor              764586.18%
# 4  GA49547  Washington    Male  High School or Below              536307.65%
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
state_column = data['state'].unique()
print(state_column)
# Out:
# ['Washington' 'Arizona' 'Nevada' 'California' 'Oregon' 'Cali' 'AZ' 'WA']

# %%
valid_state = {'AZ': 'Arizona', 'Cali': 'California', 'WA': 'Washington'}
data['state'] = data['state'].rename(valid_state)
data.head(5)
# Out:
#   customer       state  gender             education customer_lifetime_value  \
# 0  RB50392  Washington  Female                Master                     NaN
# 1  QZ44356     Arizona  Female              Bachelor              697953.59%
# 2  AI49188      Nevada  Female              Bachelor             1288743.17%
# 3  WW63253  California    Male              Bachelor              764586.18%
# 4  GA49547  Washington    Male  High School or Below              536307.65%
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
education_column = data['education'].unique()
print(education_column)
# Out:
# ['Master' 'Bachelor' 'High School or Below' 'College' 'Bachelors' 'Doctor']

# %%
valid_education = {'Bachelors':'Bachelor'}
data['education'] = data['education'].replace(valid_education)
data.head(5)
# Out:
#   customer       state  gender             education customer_lifetime_value  \
# 0  RB50392  Washington  Female                Master                     NaN
# 1  QZ44356     Arizona  Female              Bachelor              697953.59%
# 2  AI49188      Nevada  Female              Bachelor             1288743.17%
# 3  WW63253  California    Male              Bachelor              764586.18%
# 4  GA49547  Washington    Male  High School or Below              536307.65%
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
customer_lifetime_value_column = data['customer_lifetime_value'].unique()
print(customer_lifetime_value_column)
# Out:
# [nan '697953.59%' '1288743.17%' ... '2031499.76%' '323912.47%'
#  '899704.02%']

# %%
data['customer_lifetime_value'] = data['customer_lifetime_value'].str.replace('%','')
data['customer_lifetime_value'] = pd.to_numeric(data['customer_lifetime_value'] , errors='coerce')/100
data['customer_lifetime_value']
# Out:
# 0              NaN
# 1        6979.5359
# 2       12887.4317
# 3        7645.8618
# 4        5363.0765
#            ...
# 1066     3059.5503
# 1067    20314.9976
# 1068     3239.1247
# 1069     4626.8011
# 1070     8997.0402
# Name: customer_lifetime_value, Length: 1071, dtype: float64

# %%
mean = data['customer_lifetime_value'].mean()
mean
# Out:
# 7936.902593445692

# %%
data['customer_lifetime_value'] = data['customer_lifetime_value'].fillna(mean)
data['customer_lifetime_value']
# Out:
# 0        7936.902593
# 1        6979.535900
# 2       12887.431700
# 3        7645.861800
# 4        5363.076500
#             ...
# 1066     3059.550300
# 1067    20314.997600
# 1068     3239.124700
# 1069     4626.801100
# 1070     8997.040200
# Name: customer_lifetime_value, Length: 1071, dtype: float64

# %%
data['customer_lifetime_value'] = data['customer_lifetime_value'].round(decimals = 2)
data['customer_lifetime_value']
# Out:
# 0        7936.90
# 1        6979.54
# 2       12887.43
# 3        7645.86
# 4        5363.08
#           ...
# 1066     3059.55
# 1067    20315.00
# 1068     3239.12
# 1069     4626.80
# 1070     8997.04
# Name: customer_lifetime_value, Length: 1071, dtype: float64

# %%
vehicle_class_column = data['vehicle_class'].unique()
print(vehicle_class_column)
# Out:
# ['Four-Door Car' 'Two-Door Car' 'SUV' 'Luxury SUV' 'Sports Car'
#  'Luxury Car']

# %%
valid_vehicle_class={'Luxury SUV' : 'Luxury', 'Sports Car' : 'Luxury' , 'Luxury Car':'Luxury'}
data['vehicle_class'] = data['vehicle_class'].replace(valid_vehicle_class)
data.head(5)
# Out:
#   customer       state  gender             education  customer_lifetime_value  \
# 0  RB50392  Washington  Female                Master                  7936.90
# 1  QZ44356     Arizona  Female              Bachelor                  6979.54
# 2  AI49188      Nevada  Female              Bachelor                 12887.43
# 3  WW63253  California    Male              Bachelor                  7645.86
# 4  GA49547  Washington    Male  High School or Below                  5363.08
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
vehicle_class_column = data['vehicle_class'].unique()
print(vehicle_class_column)
# Out:
# ['Four-Door Car' 'Two-Door Car' 'SUV' 'Luxury']

# %%
data.isnull().sum()
# Out:
# customer                     0
# state                        0
# gender                       0
# education                    0
# customer_lifetime_value      0
# income                       0
# monthly_premium_auto         0
# number_of_open_complaints    0
# policy_type                  0
# vehicle_class                0
# total_claim_amount           0
# dtype: int64

# %%
number_of_open_complaints_column = data['number_of_open_complaints'].unique
print(number_of_open_complaints_column)
# Out:
# <bound method Series.unique of 0       1/0/00
# 1       1/0/00
# 2       1/0/00
# 3       1/0/00
# 4       1/0/00
#          ...
# 1066    1/1/00
# 1067    1/2/00
# 1068    1/0/00
# 1069    1/0/00
# 1070    1/0/00
# Name: number_of_open_complaints, Length: 1071, dtype: object>

# %%
new_list = []
for item in data['number_of_open_complaints']:
    index_item = item.split('/')[1]
    new_list.append(str(index_item))
data['number_of_open_complaints'] = new_list
data.head(5)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[43], line 3
#       1 new_list = []
#       2 for item in data['number_of_open_complaints']:
# ----> 3     index_item = item.split('/')[1]
#       4     new_list.append(str(index_item))
#       5 data['number_of_open_complaints'] = new_list
#
# IndexError: list index out of range

# %%
pd.to_numeric(data['number_of_open_complaints'] , errors='coerce')
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1066    1
# 1067    2
# 1068    0
# 1069    0
# 1070    0
# Name: number_of_open_complaints, Length: 1071, dtype: int64

# %%
data.head(5)
# Out:
#   customer       state  gender             education  customer_lifetime_value  \
# 0  RB50392  Washington  Female                Master                  7936.90
# 1  QZ44356     Arizona  Female              Bachelor                  6979.54
# 2  AI49188      Nevada  Female              Bachelor                 12887.43
# 3  WW63253  California    Male              Bachelor                  7645.86
# 4  GA49547  Washington    Male  High School or Below                  5363.08
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                         0   Personal Auto
# 1      0.0                  94.0                         0   Personal Auto
# 2  48767.0                 108.0                         0   Personal Auto
# 3      0.0                 106.0                         0  Corporate Auto
# 4  36357.0                  68.0                         0   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
# Lab | Customer Analysis Round 3

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
data.head(10)
# Out:
#   customer       state  gender             education  customer_lifetime_value  \
# 0  RB50392  Washington  Female                Master                  7936.90
# 1  QZ44356     Arizona  Female              Bachelor                  6979.54
# 2  AI49188      Nevada  Female              Bachelor                 12887.43
# 3  WW63253  California    Male              Bachelor                  7645.86
# 4  GA49547  Washington    Male  High School or Below                  5363.08
# 5  OC83172      Oregon  Female              Bachelor                  8256.30
# 6  XZ87318      Oregon  Female               College                  5380.90
# 7  CF85061     Arizona    Male                Master                  7216.10
# 8  DY87989      Oregon    Male              Bachelor                 24127.50
# 9  BQ94931      Oregon  Female               College                  7388.18
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# ...

# %%
data.describe()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count              1071.000000   1071.000000           1071.000000
# mean               7936.902521  39295.701214            193.234360
# std                6425.757110  30469.427060           1601.190369
# min                2004.350000      0.000000             61.000000
# 25%                4048.535000  14072.000000             68.000000
# 50%                5887.180000  36234.000000             83.000000
# 75%                8945.210000  64631.000000            109.500000
# max               58166.550000  99960.000000          35354.000000
#
#        total_claim_amount
# count         1071.000000
# mean           404.986909
# std            293.027260
# min              0.382107
# 25%            202.157702
# 50%            354.729129
# 75%            532.800000
# max           2893.239678

# %%
data['gender'].value_counts()
# Out:
# Female    619
# Male      452
# Name: gender, dtype: int64

# %%
sns.countplot(x='gender', data=data)
plt.show()

# %%
sns.barplot(x='state' , y='income' , data=data)
plt.show()

# %%
sns.barplot(x='policy_type' , y='total_claim_amount' , data=data)
plt.show()

# %%
sns.countplot(x='vehicle_class' , hue='education', data=data)
plt.show()

# %%
correlations_matrix = data.corr()
correlations_matrix
# Out:
# /var/folders/ph/whcjxjz51rl8p5yk1zr3jlqw0000gn/T/ipykernel_42126/3143150681.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlations_matrix = data.corr()
#                          customer_lifetime_value    income  \
# customer_lifetime_value                 1.000000  0.041610
# income                                  0.041610  1.000000
# monthly_premium_auto                    0.005027  0.049100
# total_claim_amount                      0.131452 -0.361282
#
#                          monthly_premium_auto  total_claim_amount
# customer_lifetime_value              0.005027            0.131452
# income                               0.049100           -0.361282
# monthly_premium_auto                 1.000000           -0.040493
# total_claim_amount                  -0.040493            1.000000

# %%
sns.heatmap(correlations_matrix, annot=True)
plt.show()
